# %%
import sys
import os
sys.path.append(os.getcwd())

# %%
print(sys.path)
# Out:
# ['', '/home/loic/.virtualenvs/dpp/lib/python35.zip', '/home/loic/.virtualenvs/dpp/lib/python3.5', '/home/loic/.virtualenvs/dpp/lib/python3.5/plat-x86_64-linux-gnu', '/home/loic/.virtualenvs/dpp/lib/python3.5/lib-dynload', '/usr/lib/python3.5', '/usr/lib/python3.5/plat-x86_64-linux-gnu', '/home/loic/.virtualenvs/dpp/lib/python3.5/site-packages', '/home/loic/.virtualenvs/dpp/lib/python3.5/site-packages/IPython/extensions', '/home/loic/.ipython', '/home/loic/repos/eu-structural-funds']

# %%
from common.bootstrap import collect_sources
from pandas import DataFrame

mappings = DataFrame()

for source in collect_sources():
    mappings = mappings.append(source.fields_mapping, ignore_index=True)

# %%
mappings.head()
# Out:
#   decimal description mapping              maps_to missingValue  \
# 0     NaN         NaN     NaN     beneficiary_name          NaN
# 1     NaN         NaN     NaN  beneficiary_address          NaN
# 2     NaN         NaN     NaN         project_name          NaN
# 3     NaN         NaN     NaN  project_description          NaN
# 4     NaN         NaN     NaN         total_amount          NaN
#
#                         name                 pipeline_id  \
# 0  Begünstigte/r beneficiary  AT.austria/AT11.burgenland
# 1        Adresse Begünstigte  AT.austria/AT11.burgenland
# 2               Projekttitel  AT.austria/AT11.burgenland
# 3        Projektbeschreibung  AT.austria/AT11.burgenland
# 4    öffentliche Beteiligung  AT.austria/AT11.burgenland
#
#                                      translates_to translation type
# 0                          Name of the Beneficiary         NaN  NaN
# 1                            adress of beneficiary         NaN  NaN
# 2                              Name of the Project         NaN  NaN
# 3                              Project description         NaN  NaN
# 4  total amount of public expenditure EU and local         NaN  NaN

# %%
fiscal_fields = mappings.groupby('maps_to').size().sort_values(ascending=False)
fiscal_fields = fiscal_fields.reindex(fiscal_fields.index.rename('Fiscal field'))
DataFrame(fiscal_fields, columns=['Count'])
# Out:
#                           Count
# Fiscal field
# beneficiary_name             94
# project_name                 89
# total_amount                 69
# total_amount_eligible        68
# starting_date                45
# project_description          44
# eu_cofinancing_amount        40
# completion_date              36
# approval_date                32
# beneficiary_country          19
# beneficiary_postal_code      18
# project_id                   17
# beneficiary_city             16
# beneficiary_nuts_region      14
# theme_code                   14
# fund_acronym                 12
# theme_name                   12
# member_state_amount          10
# cci_program_code              9
# beneficiary_address           8
# cci_program_title             7
# priority_label                7
# final_payment_date            7
# priority_number               6
# beneficiary_nuts_code         4
# total_amount_applied          3
# start_date                    2
# beneficiary_url               2
# beneficiary_country_code      2
# third_party_amount            1

# %%
fiscal_fields
# Out:
# Fiscal field
# beneficiary_name            94
# project_name                89
# total_amount                69
# total_amount_eligible       68
# starting_date               45
# project_description         44
# eu_cofinancing_amount       40
# completion_date             36
# approval_date               32
# beneficiary_country         19
# beneficiary_postal_code     18
# project_id                  17
# beneficiary_city            16
# beneficiary_nuts_region     14
# theme_code                  14
# fund_acronym                12
# theme_name                  12
# member_state_amount         10
# cci_program_code             9
# beneficiary_address          8
# cci_program_title            7
# priority_label               7
# final_payment_date           7
# priority_number              6
# beneficiary_nuts_code        4
# total_amount_applied         3
# start_date                   2
# beneficiary_url              2
# beneficiary_country_code     2
# third_party_amount           1
# dtype: int64

# %%
from bokeh.charts import Bar, output_notebook, show
from bokeh.sampledata.autompg import autompg as df
output_notebook()

p = Bar(fiscal_fields, legend=None, plot_width=900)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3ff9643f-de97-42c6-8c09-96cfc1453473">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="98266443-7fff-4aa3-9325-479014942f89"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#98266443-7fff-4aa3-9325-479014942f89").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("98266443-7fff-4aa3-9325-479014942f89");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '98266443-7fff-4aa3-9325-479014942f89' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ad3b0052-9220-499b-88f3-41be65138621":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"55d0e60b-50d5-496f-ac47-57b22807dca9","type":"Title"},{"attributes":{"plot":{"id":"157b7bdf-58d3-4927-822a-f9cfb43e742b","subtype":"Chart","type":"Plot"}},"id":"3cb3796c-ef04-4f9b-8c68-8723bb831b87","type":"SaveTool"},{"attributes":{"data_source":{"id":"d0c008db-c73d-4be9-80b9-6cd042f44004","type":"ColumnDataSource"},"glyph":{"id":"6e8953a0-e92d-43cc-9b72-e2a037e2a1c2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5b342054-cdf3-4882-b732-98701e240c8f","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"aa5ade2e-35b2-4324-b44e-eac62c705a16","type":"ColumnDataSource"},"glyph":{"id":"f5afaa22-0b29-4d69-92d5-af561a8a00da","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5b234fbb-228e-4439-9dd2-ca8f41bcdfd4","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"157b7bdf-58d3-4927-822a-f9cfb43e742b","subtype":"Chart","type":"Plot"}},"id":"16debced-469e-490f-bf37-e0a4d64b8bb4","type":"ResetTool"},{"attributes":{"data_source":{"id":"8aad2a85-2156-4f09-a436-c4ef9b7dfa57","type":"ColumnDataSource"},"glyph":{"id":"3cd11448-e550-4560-b2de-f8bd6f189057","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9eaea709-a477-4397-be06-c314884ea713","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"41074565-6c0a-42d7-afb1-9aa2de5b0b67","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c84e1810-fcce-437c-a502-61219a05b634","type":"Rect"},{"attributes":{"data_source":{"id":"afa6f1ce-2b02-484f-b143-d23e0da5fda6","type":"ColumnDataSource"},"glyph":{"id":"3606b294-5f70-4ba9-b5cf-cf3dc560f491","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"18c7d339-10db-4bdc-a7b9-f00c2c816bd6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","width","line_color","height","fill_alpha","label","line_alpha","color","x"],"data":{"chart_index":[{"index":"beneficiary_url"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"index":["beneficiary_url"],"label":[{"index":"beneficiary_url"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["beneficiary_url"],"y":[1.0]}},"id":"5a871fa3-a327-474d-a3a5-02afd3ddb0cc","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"e4c6181a-7dbd-440a-b778-925c4ff894a0","type":"BoxAnnotation"},"plot":{"id":"157b7bdf-58d3-4927-822a-f9cfb43e742b","subtype":"Chart","type":"Plot"}},"id":"3fd7adfd-bc01-49bd-ba4c-492c4872a592","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b872a080-0afa-492f-9289-2afc52de5bdc","type":"Rect"},{"attributes":{"data_source":{"id":"3a80a5f6-ba60-4871-941a-b5d67d2fd804","type":"ColumnDataSource"},"glyph":{"id":"c422190c-cd9c-4377-a30b-018f7eb6c2ce","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"abbd3b44-070e-4873-b53f-e22c8a9b2da3","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["approval_date","beneficiary_address","beneficiary_city","beneficiary_country","beneficiary_country_code","beneficiary_name","beneficiary_nuts_code","beneficiary_nuts_region","beneficiary_postal_code","beneficiary_url","cci_program_code","cci_program_title","completion_date","eu_cofinancing_amount","fin ...

# %%
minimum_fields = ['beneficary_name', 'project_name', 'total_amount', 'fund_acronym']
